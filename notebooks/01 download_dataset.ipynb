# %%
import numpy as numpy

# %%
import json
with open('../artifacts/kaggle.json','r')as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'duminduwick', 'key': 'ca3cd33baff521c4e50d93dc9656d660'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-2.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from kaggle) (6.3.0)
# Collecting jupytext (from kaggle)
#   Downloading jupytext-1.19.1-py3-none-any.whl.metadata (15 kB)
# Collecting kagglesdk<1.0,>=0.1.23 (from kaggle)
#   Downloading kagglesdk-0.1.23-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from kaggle) (26.2)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: python-dateutil in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from kaggle) (2.33.1)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from kaggle) (2.7.0)
# Requirement already satisfied: webencodings in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from bleach->kaggle) (0.5.1)
# Collecting markdown-it-py>=1.0 (from jupytext->kaggle)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mdit-py-plugins (from jupytext->kaggle)
#   Downloading mdit_py_plugins-0.6.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: nbformat in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jupytext->kaggle) (6.0.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=1.0->jupytext->kaggle)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (5.15.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.15.0)
# Requirement already satisfied: six>=1.5 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from requests->kaggle) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from requests->kaggle) (2026.4.22)
# Requirement already satisfied: colorama in C:\Users\sayum\Desktop\Sentiment_analysis_project\env\Lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-2.1.2-py3-none-any.whl (110 kB)
# Downloading kagglesdk-0.1.23-py3-none-any.whl (217 kB)
# Downloading jupytext-1.19.1-py3-none-any.whl (170 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mdit_py_plugins-0.6.0-py3-none-any.whl (66 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, mdurl, markdown-it-py, kagglesdk, mdit-py-plugins, jupytext, kaggle
#
#    ---- -----------------------------------  1/10 [tqdm]
#    ------------ ---------------------------  3/10 [protobuf]
#    ------------ ---------------------------  3/10 [protobuf]
#    ------------ ---------------------------  3/10 [protobuf]
#    ---------------- -----------------------  4/10 [mdurl]
#    -------------------- -------------------  5/10 [markdown-it-py]
#    -------------------- -------------------  5/10 [markdown-it-py]
#    -------------------- -------------------  5/10 [markdown-it-py]
#    -------------------- -------------------  5/10 [markdown-it-py]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ------------------------ ---------------  6/10 [kagglesdk]
#    ---------------------------- -----------  7/10 [mdit-py-plugins]
#    ---------------------------- -----------  7/10 [mdit-py-plugins]
#    -------------------------------- -------  8/10 [jupytext]
#    -------------------------------- -------  8/10 [jupytext]
#    -------------------------------- -------  8/10 [jupytext]
#    -------------------------------- -------  8/10 [jupytext]
#    ------------------------------------ ---  9/10 [kaggle]
#    ------------------------------------ ---  9/10 [kaggle]
#    ---------------------------------------- 10/10 [kaggle]
#
# Successfully installed jupytext-1.19.1 kaggle-2.1.2 kagglesdk-0.1.23 markdown-it-py-4.2.0 mdit-py-plugins-0.6.0 mdurl-0.1.2 protobuf-7.34.1 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.3
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/kaggle/

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path='../artifacts')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile

# Path to the zip file
zip_path = '../artifacts/sentiment-analysis-dataset.zip'

# Folder where files will be extracted
extract_path = '../artifacts/'

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!
